# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from hickathon_2023.data_preprocessing import get_data_preprocessor
from hickathon_2023.feature_extraction import FeatureExtractor
from hickathon_2023.model import get_model
from hickathon_2023.utils import Pipeline, load_data

SMALL_DATASET = True
Y_FEATURE = "energy_consumption_per_annum"

# %%
if SMALL_DATASET:
    path = "datasets/small/"
else:
    path = "datasets/"


def get_data():
    X_train, y_train = load_data(
        X_path=path + "train/train_features_sent.csv",
        y_path=path + "train/train_labels_sent.csv",
        y_feature=Y_FEATURE,
    )
    X_test, _ = load_data(X_path=path + "test/test_features_sent.csv")

    return X_train, y_train, X_test


X_train, y_train, X_test = get_data()

# %% [markdown]
# # 1. Feature extraction

# %%
X_train.head()
# Out:
#    level_0 additional_heat_generators  \
# 0    19594                         []
# 1    19099     [wood stove or insert]
# 2   -29928                         []
# 3     3127                         []
# 4   -22101                         []
#
#                             additional_water_heaters    altitude  area_code  \
# 0                                                NaN  177.165359        654
# 1                             electric water heating   91.863518        354
# 2                                                NaN  823.490845        347
# 3                                                NaN  341.207367        815
# 4  thermodynamic electric hot water (heat pump or...  869.422607        659
#
#   balcony_depth bearing_wall_material         building_category  \
# 0           NaN              CONCRETE                   [condo]
# 1           NaN           AGGLOMERATE        [individual house]
# 2           NaN              CONCRETE        [individual house]
# 3           NaN          INDETERMINED  [condo,individual house]
# 4           NaN           AGGLOMERATE        [individual house]
#
#   building_class  building_height_ft  ... wall_insulation_type  \
# 0      [2 to 11]           42.322838  ...             internal
# 1   [individual]           12.795276  ...             internal
# 2   [individual]           15.748032  ...             internal
# 3  [12+,2 to 11]           36.089241  ...             internal
# 4      [2 to 11]           13.451444  ...             internal
#
#                                        water_heaters  \
# 0                            [electric storage tank]
# 1         [solar water heater,electric storage tank]
# 2                       [low temperature gas boiler]
# 3                            [electric storage tank]
# 4  [standard gas boiler,thermodynamic electric ho...
#
#                          water_heating_energy_source  water_heating_type  \
# 0                                        electricity          individual
# 1                                        electricity          individual
# 2                                                gas          individual
# 3                                        electricity          individual
# 4  thermodynamic electric hot water (pac or tank)...          individual
#
#   window_filling_type        window_frame_material window_glazing_type  \
# 0    argon or krypton                          pvc      double glazing
# 1    argon or krypton  metal without thermal break      double glazing
# 2                 NaN                         wood      single glazing
# 3             dry air                          pvc      double glazing
# 4    argon or krypton                         wood      double glazing
#
#   window_heat_retention_factor    window_orientation  \
# 0                     1.116894  [east or west,north]
# 1                     1.289049       [est,north,sud]
# 2                     1.212343           [north,sud]
# 3                     1.116894             [est,sud]
# 4                     1.599851        [est,west,sud]
#
#   window_thermal_conductivity
# 0                   16.057268
# 1                   22.149689
# 2                   23.781612
# 3                   15.347292
# 4                   13.290529
#
# [5 rows x 71 columns]

# %%
feature_extractor = FeatureExtractor()
X_train = feature_extractor.transform(X_train)
X_train.head()
# Out:
#    level_0    altitude  area_code  balcony_depth  building_height_ft  \
# 0    19594  177.165359        654              0           42.322838
# 1    19099   91.863518        354              0           12.795276
# 2   -29928  823.490845        347              0           15.748032
# 3     3127  341.207367        815              0           36.089241
# 4   -22101  869.422607        659              0           13.451444
#
#    building_total_area_sqft building_type  building_use_type_code  \
# 0               3562.850830          Flat                       2
# 1               1754.515747         House                       1
# 2                968.750977         House                       1
# 3                       NaN          Flat                       2
# 4               1162.501221         House                       1
#
#   building_use_type_description  building_year  ... water_heating_electricity  \
# 0      Residential multi-family         2002.0  ...                      True
# 1     Residential single-family         1985.0  ...                      True
# 2     Residential single-family         1970.0  ...                     False
# 3      Residential multi-family         1993.0  ...                      True
# 4     Residential single-family         1965.0  ...                      True
#
#    water_heating_wood  water_heating_network water_heating_coal  \
# 0               False                  False              False
# 1               False                  False              False
# 2               False                  False              False
# 3               False                  False              False
# 4               False                  False              False
#
#    window_orientation_north  window_orientation_east  \
# 0                      True                     True
# 1                      True                     True
# 2                      True                    False
# 3                     False                     True
# 4                     False                     True
#
#    window_orientation_south  window_orientation_west lower_year_building  \
# 0                     False                     True              1989.0
# 1                      True                    False              1970.0
# 2                      True                    False              1949.0
# 3                      True                    False              1989.0
# 4                      True                     True              1949.0
#
#   upper_year_building
# 0              1999.0
# 1              1988.0
# 2              1970.0
# 3              1999.0
# 4              1970.0
#
# [5 rows x 112 columns]

# %% [markdown]
# # 2. Data preprocessing

# %%
# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer

# inputer = ColumnTransformer(
#     transformers=[
#         ("inputer_median", SimpleImputer(strategy="median"),
#                 [
#                     "altitude",
#                     "building_height_ft",
#                     "building_total_area_sqft",
#                     "living_area_sqft",
#                     "lowe_floor_thermal_conductivity",
#                     "outer_wall_thermal_conductivity",
#                     "percentage_glazed_surfaced",
#                     "upper_floor_thermal_conductivity",
#                     "window_heat_retention_factor",
#                     "window_thermal_conductivity",
#                 ])])
# inputer.fit_transform(X_train).isna().sum()

# %%
data_preprocessor = get_data_preprocessor()
X_train = data_preprocessor.fit_transform(X_train)
X_train.shape
# Out:
# (10107, 89)

# %%
X_train
# Out:
#        add_heat_generators_boiler  add_heat_generators_heat_pump  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ...                           ...                            ...
# 10102                       False                          False
# 10103                       False                          False
# 10104                       False                          False
# 10105                       False                          False
# 10106                       False                          False
#
#        add_heat_generators_stove    altitude  area_code  balcony_depth  \
# 0                          False  177.165359        654              0
# 1                           True   91.863518        354              0
# 2                          False  823.490845        347              0
# 3                          False  341.207367        815              0
# 4                          False  869.422607        659              0
# ...                          ...         ...        ...            ...
# 10102                      False  580.708679        637              0
# 10103                      False   78.740158        356              0
# 10104                      False   78.740158        156              0
# 10105                      False  291.994751        660              0
# 10106                      False  177.165359        858              0
#
#        bearing_wall_agglomerate  bearing_wall_bricks  bearing_wall_chipboard  \
# 0                         False                False                   False
# 1                          True                False                   False
# 2                         False                False                   False
# 3                         False                False                   False
# 4                          True                False                   False
# ...                         ...                  ...                     ...
# 10102                     False                False                   False
# 10103                     False                 True                   False
# 10104                     False                False                   False
# 10105                     False                 True                   False
# 10106                     False                 True                   False
#
#        bearing_wall_concrete  ...  water_heating_wood  window_filling_type  \
# 0                       True  ...               False                    2
# 1                      False  ...               False                    2
# 2                       True  ...               False                    0
# 3                      False  ...               False                    1
# 4                      False  ...               False                    2
# ...                      ...  ...                 ...                  ...
# 10102                  False  ...               False                    0
# 10103                  False  ...               False                    1
# 10104                  False  ...               False                    0
# 10105                  False  ...               False                    1
# 10106                  False  ...               False                    1
#
#        window_frame_material  window_glazing_type  \
# 0                         -1                    1
# 1                          2                    1
# 2                          1                    0
# 3                         -1                    1
# 4                          1                    1
# ...                      ...                  ...
# 10102                      1                    0
# 10103                      1                    0
# 10104                     -1                    1
# 10105                      1                    1
# 10106                      1                    0
#
#        window_heat_retention_factor  window_orientation_east  \
# 0                          1.116894                     True
# 1                          1.289049                     True
# 2                          1.212343                    False
# 3                          1.116894                     True
# 4                          1.599851                     True
# ...                             ...                      ...
# 10102                      1.212343                     True
# 10103                      1.212343                     True
# 10104                      1.084204                     True
# 10105                      1.133072                     True
# 10106                      1.212343                     True
#
#        window_orientation_north  window_orientation_south  \
# 0                          True                     False
# 1                          True                      True
# 2                          True                      True
# 3                         False                      True
# 4                         False                      True
# ...                         ...                       ...
# 10102                     False                      True
# 10103                      True                     False
# 10104                     False                     False
# 10105                      True                      True
# 10106                      True                      True
#
#        window_orientation_west  window_thermal_conductivity
# 0                         True                    16.057268
# 1                        False                    22.149689
# 2                        False                    23.781612
# 3                        False                    15.347292
# 4                         True                    13.290529
# ...                        ...                          ...
# 10102                    False                    28.040001
# 10103                     True                    25.454838
# 10104                     True                    16.779108
# 10105                    False                    14.649374
# 10106                     True                    23.781612
#
# [10107 rows x 89 columns]

# %% [markdown]
# Inputer

# %%
for column in [
    "altitude",
    "building_height_ft",
    "building_total_area_sqft",
    "living_area_sqft",
    "lowe_floor_thermal_conductivity",
    "outer_wall_thermal_conductivity",
    "percentage_glazed_surfaced",
    "upper_floor_thermal_conductivity",
    "window_heat_retention_factor",
    "window_thermal_conductivity",
]:
    X_train[column] = X_train[column].fillna(X_train[column].median())

for column in [
    "nb_commercial_units",
    "nb_dwellings",
    "nb_housing_units",
]:
    X_train[column] = X_train[column].fillna(0)

X_train["building_use_type_code"] = X_train["building_use_type_code"].fillna(1)

# %% [markdown]
# Convert dtypes

# %%
from hickathon_2023.data_preprocessing import convert_dtypes

X_train = convert_dtypes(X_train)

# %% [markdown]
# OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
from hickathon_2023.features import FEATURES_ONEHOT
import numpy as np

encoder = OneHotEncoder(handle_unknown="ignore", sparse=False, dtype=bool)

print(X_train.shape)

X_train_onehot = encoder.fit_transform(X_train[FEATURES_ONEHOT])
X_train = np.concatenate(
    [X_train.drop(columns=FEATURES_ONEHOT).to_numpy(), X_train_onehot], axis=1
)

print(X_train.shape)
# Out:
# (10107, 89)
# (10107, 221)

# %%
if SMALL_DATASET:
    np.save("datasets/train/X_small.npy", X_train)
else:
    np.save("datasets/train/X_big.npy", X_train)

# %% [markdown]
# # X_test

# %%
print(X_test.shape)

X_test = feature_extractor.transform(X_test)

print(X_test.shape)

X_test = data_preprocessor.transform(X_test)

print(X_test.shape)

for column in [
    "altitude",
    "building_height_ft",
    "building_total_area_sqft",
    "living_area_sqft",
    "lowe_floor_thermal_conductivity",
    "outer_wall_thermal_conductivity",
    "percentage_glazed_surfaced",
    "upper_floor_thermal_conductivity",
    "window_heat_retention_factor",
    "window_thermal_conductivity",
]:
    X_test[column] = X_test[column].fillna(X_test[column].median())

for column in [
    "nb_commercial_units",
    "nb_dwellings",
    "nb_housing_units",
]:
    X_test[column] = X_test[column].fillna(0)

X_test["building_use_type_code"] = X_test["building_use_type_code"].fillna(1)

X_test = convert_dtypes(X_test)

print(X_test.shape)

X_test_onehot = encoder.transform(X_test[FEATURES_ONEHOT])
X_test = np.concatenate(
    [X_test.drop(columns=FEATURES_ONEHOT).to_numpy(), X_test_onehot], axis=1
)

print(X_test.shape)
# Out:
# (4949, 71)
# (4949, 112)
# (4949, 89)
# (4949, 89)
# (4949, 221)

# %%
if SMALL_DATASET:
    np.save("datasets/test/X_test_small.npy", X_train)
else:
    np.save("datasets/test/X_test_big.npy", X_train)

# %%
# df = pd.DataFrame(X_train)

# %%
# df.isna().sum()[df.isna().sum() > 0]

# %%
# df_test = pd.DataFrame(X_test)

# %%
# df_test.isna().sum()[df_test.isna().sum() > 0]

# %%
# submission_df = pd.read_csv(path + "sample_submission_sent.csv")
# submission_df[Y_FEATURE] = y_test_pred
# submission_df.to_csv(path + "submission_sent.csv")

# %%
# for i in range(df.shape[0]):
#     for j in range(df.shape[1]):
#         if type(df.iloc[i, j]) == str:
#             print(df.iloc[i, j])
