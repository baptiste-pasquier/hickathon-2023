# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from hickathon_2023.data_preprocessing import get_data_preprocessor
from hickathon_2023.feature_extraction import FeatureExtractor
from hickathon_2023.model import get_model
from hickathon_2023.utils import Pipeline, load_data

SMALL_DATASET = True
Y_FEATURE = "energy_consumption_per_annum"

# %%
if SMALL_DATASET:
    path = "datasets/small/"
else:
    path = "datasets/"


def get_data():
    X_train, y_train = load_data(
        X_path=path + "train/train_features_sent.csv",
        y_path=path + "train/train_labels_sent.csv",
        y_feature=Y_FEATURE,
    )
    X_test, _ = load_data(X_path=path + "test/test_features_sent.csv")

    return X_train, y_train, X_test


X_train, y_train, X_test = get_data()

# %% [markdown]
# # 1. Feature extraction

# %%
X_train.head()
# Out:
#    level_0 additional_heat_generators  \
# 0    19594                         []
# 1    19099     [wood stove or insert]
# 2   -29928                         []
# 3     3127                         []
# 4   -22101                         []
#
#                             additional_water_heaters    altitude  area_code  \
# 0                                                NaN  177.165359        654
# 1                             electric water heating   91.863518        354
# 2                                                NaN  823.490845        347
# 3                                                NaN  341.207367        815
# 4  thermodynamic electric hot water (heat pump or...  869.422607        659
#
#   balcony_depth bearing_wall_material         building_category  \
# 0           NaN              CONCRETE                   [condo]
# 1           NaN           AGGLOMERATE        [individual house]
# 2           NaN              CONCRETE        [individual house]
# 3           NaN          INDETERMINED  [condo,individual house]
# 4           NaN           AGGLOMERATE        [individual house]
#
#   building_class  building_height_ft  ... wall_insulation_type  \
# 0      [2 to 11]           42.322838  ...             internal
# 1   [individual]           12.795276  ...             internal
# 2   [individual]           15.748032  ...             internal
# 3  [12+,2 to 11]           36.089241  ...             internal
# 4      [2 to 11]           13.451444  ...             internal
#
#                                        water_heaters  \
# 0                            [electric storage tank]
# 1         [solar water heater,electric storage tank]
# 2                       [low temperature gas boiler]
# 3                            [electric storage tank]
# 4  [standard gas boiler,thermodynamic electric ho...
#
#                          water_heating_energy_source  water_heating_type  \
# 0                                        electricity          individual
# 1                                        electricity          individual
# 2                                                gas          individual
# 3                                        electricity          individual
# 4  thermodynamic electric hot water (pac or tank)...          individual
#
#   window_filling_type        window_frame_material window_glazing_type  \
# 0    argon or krypton                          pvc      double glazing
# 1    argon or krypton  metal without thermal break      double glazing
# 2                 NaN                         wood      single glazing
# 3             dry air                          pvc      double glazing
# 4    argon or krypton                         wood      double glazing
#
#   window_heat_retention_factor    window_orientation  \
# 0                     1.116894  [east or west,north]
# 1                     1.289049       [est,north,sud]
# 2                     1.212343           [north,sud]
# 3                     1.116894             [est,sud]
# 4                     1.599851        [est,west,sud]
#
#   window_thermal_conductivity
# 0                   16.057268
# 1                   22.149689
# 2                   23.781612
# 3                   15.347292
# 4                   13.290529
#
# [5 rows x 71 columns]

# %%
feature_extractor = FeatureExtractor()
X_train = feature_extractor.transform(X_train)
X_train.head()
# Out:
#    level_0    altitude  area_code  balcony_depth  building_height_ft  \
# 0    19594  177.165359        654              0           42.322838
# 1    19099   91.863518        354              0           12.795276
# 2   -29928  823.490845        347              0           15.748032
# 3     3127  341.207367        815              0           36.089241
# 4   -22101  869.422607        659              0           13.451444
#
#    building_total_area_sqft building_type  building_use_type_code  \
# 0               3562.850830          Flat                       2
# 1               1754.515747         House                       1
# 2                968.750977         House                       1
# 3                       NaN          Flat                       2
# 4               1162.501221         House                       1
#
#   building_use_type_description  building_year  ...  water_heating_network  \
# 0      Residential multi-family         2002.0  ...                  False
# 1     Residential single-family         1985.0  ...                  False
# 2     Residential single-family         1970.0  ...                  False
# 3      Residential multi-family         1993.0  ...                  False
# 4     Residential single-family         1965.0  ...                  False
#
#    water_heating_coal  window_orientation_north window_orientation_east  \
# 0               False                      True                    True
# 1               False                      True                    True
# 2               False                      True                   False
# 3               False                     False                    True
# 4               False                     False                    True
#
#    window_orientation_south  window_orientation_west  lower_year_building  \
# 0                     False                     True               1989.0
# 1                      True                    False               1970.0
# 2                      True                    False               1949.0
# 3                      True                    False               1989.0
# 4                      True                     True               1949.0
#
#    upper_year_building living_to_building_area_ratio wall_area_by_conductivity
# 0               1999.0                      0.090634             578250.014173
# 1               1988.0                      0.674847             175745.645845
# 2               1970.0                      1.044444             160726.925496
# 3               1999.0                           NaN                       NaN
# 4               1970.0                      1.018519             228356.302939
#
# [5 rows x 118 columns]

# %% [markdown]
# # 2. Data preprocessing

# %%
data_preprocessor = get_data_preprocessor()
X_train = data_preprocessor.fit_transform(X_train)
X_train.shape
# Out:
# c:\Users\pasqu\AppData\Local\pypoetry\Cache\virtualenvs\hickathon-2023-_-bbnVz2-py3.8\lib\site-packages\sklearn\preprocessing\_function_transformer.py:334: UserWarning: With transform="pandas", `func` should return a DataFrame to follow the set_output API.
#   warnings.warn(
# (10107, 263)

# %%
X_train
# Out:
#        area_code_109  area_code_127  area_code_156  area_code_158  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 10102          False          False          False          False
# 10103          False          False          False          False
# 10104          False          False           True          False
# 10105          False          False          False          False
# 10106          False          False          False          False
#
#        area_code_159  area_code_162  area_code_172  area_code_173  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 10102          False          False          False          False
# 10103          False          False          False          False
# 10104          False          False          False          False
# 10105          False          False          False          False
# 10106          False          False          False          False
#
#        area_code_178  area_code_191  ...  water_heating_coal  \
# 0              False          False  ...               False
# 1              False          False  ...               False
# 2              False          False  ...               False
# 3              False          False  ...               False
# 4              False          False  ...               False
# ...              ...            ...  ...                 ...
# 10102          False          False  ...               False
# 10103          False          False  ...               False
# 10104          False          False  ...               False
# 10105          False          False  ...               False
# 10106          False          False  ...               False
#
#        water_heating_electricity  water_heating_gas  water_heating_network  \
# 0                           True              False                  False
# 1                           True              False                  False
# 2                          False               True                  False
# 3                           True              False                  False
# 4                           True               True                  False
# ...                          ...                ...                    ...
# 10102                       True              False                  False
# 10103                      False               True                  False
# 10104                       True              False                  False
# 10105                      False               True                  False
# 10106                       True              False                  False
#
#        water_heating_oil  water_heating_wood  window_orientation_east  \
# 0                  False               False                     True
# 1                  False               False                     True
# 2                  False               False                    False
# 3                  False               False                     True
# 4                  False               False                     True
# ...                  ...                 ...                      ...
# 10102              False               False                     True
# 10103              False               False                     True
# 10104              False               False                     True
# 10105              False               False                     True
# 10106              False               False                     True
#
#        window_orientation_north  window_orientation_south  \
# 0                          True                     False
# 1                          True                      True
# 2                          True                      True
# 3                         False                      True
# 4                         False                      True
# ...                         ...                       ...
# 10102                     False                      True
# 10103                      True                     False
# 10104                     False                     False
# 10105                      True                      True
# 10106                      True                      True
#
#        window_orientation_west
# 0                         True
# 1                        False
# 2                        False
# 3                        False
# 4                         True
# ...                        ...
# 10102                    False
# 10103                     True
# 10104                     True
# 10105                    False
# 10106                     True
#
# [10107 rows x 263 columns]

# %%
X_train.columns.tolist()
# Out:
# ['area_code_109',
#  'area_code_127',
#  'area_code_156',
#  'area_code_158',
#  'area_code_159',
#  'area_code_162',
#  'area_code_172',
#  'area_code_173',
#  'area_code_178',
#  'area_code_191',
#  'area_code_204',
#  'area_code_205',
#  'area_code_213',
#  'area_code_226',
#  'area_code_228',
#  'area_code_260',
#  'area_code_264',
#  'area_code_281',
#  'area_code_299',
#  'area_code_304',
#  'area_code_345',
#  'area_code_347',
#  'area_code_351',
#  'area_code_354',
#  'area_code_356',
#  'area_code_369',
#  'area_code_374',
#  'area_code_375',
#  'area_code_377',
#  'area_code_380',
#  'area_code_382',
#  'area_code_386',
#  'area_code_387',
#  'area_code_398',
#  'area_code_400',
#  'area_code_419',
#  'area_code_451',
#  'area_code_467',
#  'area_code_471',
#  'area_code_492',
#  'area_code_498',
#  'area_code_502',
#  'area_code_518',
#  'area_code_520',
#  'area_code_542',
#  'area_code_547',
#  'area_code_559',
#  'area_code_573',
#  'area_code_585',
#  'area_code_592',
#  'area_code_597',
#  'area_code_603',
#  'area_code_615',
#  'area_code_616',
#  'area_code_637',
#  'area_code_638',
#  'area_code_643',
#  'area_code_653',
#  'area_code_654',
#  'area_code_659',
#  'area_code_660',
#  'area_code_664',
#  'area_code_671',
#  'area_code_684',
#  'area_code_689',
#  'area_code_693',
#  'area_code_701',
#  'area_code_704',
#  'area_code_706',
#  'area_code_714',
#  'area_code_735',
#  'area_code_743',
#  'area_code_746',
#  'area_code_748',
#  'area_code_752',
#  'area_code_776',
#  'area_code_784',
#  'area_code_786',
#  'area_code_794',
#  'area_code_815',
#  'area_code_816',
#  'area_code_838',
#  'area_code_843',
#  'area_code_848',
#  'area_code_849',
#  'area_code_854',
#  'area_code_858',
#  'area_code_867',
#  'area_code_872',
#  'area_code_881',
#  'area_code_901',
#  'area_code_903',
#  'area_code_952',
#  'building_type_Flat',
#  'building_type_House',
#  'building_type_Multiple dwellings',
#  'building_type_Non-residential',
#  'building_use_type_code_1.0',
#  'building_use_type_code_2.0',
#  'building_use_type_code_5.0',
#  'heating_type_0.0',
#  'heating_type_1.0',
#  'lower_floor_adjacency_type_ADJACENT BUILDING',
#  'lower_floor_adjacency_type_BURIED_WALL',
#  'lower_floor_adjacency_type_FULL_EARTH',
#  'lower_floor_adjacency_type_LNC',
#  'lower_floor_adjacency_type_OUTSIDE',
#  'lower_floor_adjacency_type_SANITARY_VACTILE',
#  'lower_floor_adjacency_type_nan',
#  'lower_floor_insulation_type_external',
#  'lower_floor_insulation_type_external+internal',
#  'lower_floor_insulation_type_insulated',
#  'lower_floor_insulation_type_internal',
#  'lower_floor_insulation_type_uninsulated',
#  'lower_floor_insulation_type_nan',
#  'main_heating_device_boil',
#  'main_heating_device_joule',
#  'main_heating_device_other',
#  'main_heating_device_pump',
#  'main_heating_device_radia',
#  'main_heating_device_stove',
#  'main_heating_fuel_coal',
#  'main_heating_fuel_gas',
#  'main_heating_fuel_oil',
#  'main_heating_fuel_other',
#  'main_heating_fuel_solar',
#  'main_heating_fuel_wood',
#  'main_water_heaters_LPG/butane/propane condensing boiler',
#  'main_water_heaters_LPG/butane/propane low temperature boiler',
#  'main_water_heaters_electric boiler',
#  'main_water_heaters_electric water heater with Joule effect',
#  'main_water_heaters_gas condensing boiler',
#  'main_water_heaters_heat network',
#  'main_water_heaters_independent gas water heater',
#  'main_water_heaters_indeterminate independent water heater',
#  'main_water_heaters_indeterminate low temperature energy boiler',
#  'main_water_heaters_low temperature gas boiler',
#  'main_water_heaters_low temperature oil boiler',
#  'main_water_heaters_oil condensing boiler',
#  'main_water_heaters_solar water heater',
#  'main_water_heaters_standard LPG/butane/propane boiler',
#  'main_water_heaters_standard gas boiler',
#  'main_water_heaters_standard indeterminate energy boiler',
#  'main_water_heaters_standard oil boiler',
#  'main_water_heaters_thermodynamic electric hot water (heat pump or tank)',
#  'main_water_heaters_wood boiler',
#  'radon_risk_level_0',
#  'radon_risk_level_1',
#  'radon_risk_level_2',
#  'roof_material_CONCRETE',
#  'roof_material_OTHERS',
#  'roof_material_SLATE',
#  'roof_material_TILES',
#  'roof_material_ZINC',
#  'thermal_inertia_0',
#  'thermal_inertia_1',
#  'thermal_inertia_2',
#  'thermal_inertia_3',
#  'ventilation_type_0',
#  'ventilation_type_1',
#  'ventilation_type_2',
#  'ventilation_type_3',
#  'ventilation_type_4',
#  'ventilation_type_5',
#  'ventilation_type_6',
#  'ventilation_type_7',
#  'water_heating_type_0.0',
#  'water_heating_type_1.0',
#  'window_filling_type_0',
#  'window_filling_type_1',
#  'window_filling_type_2',
#  'window_frame_material_-1',
#  'window_frame_material_1',
#  'window_frame_material_2',
#  'window_frame_material_4',
#  'window_glazing_type_0',
#  'window_glazing_type_1',
#  'window_glazing_type_2',
#  'altitude',
#  'building_height_ft',
#  'building_total_area_sqft',
#  'living_area_sqft',
#  'living_to_building_area_ratio',
#  'lowe_floor_thermal_conductivity',
#  'outer_wall_thermal_conductivity',
#  'percentage_glazed_surfaced',
#  'upper_floor_thermal_conductivity',
#  'wall_area_by_conductivity',
#  'window_heat_retention_factor',
#  'window_thermal_conductivity',
#  'nb_commercial_units',
#  'nb_dwellings',
#  'nb_housing_units',
#  'nb_meters',
#  'nb_units_total',
#  'add_heat_generators_boiler',
#  'add_heat_generators_heat_pump',
#  'add_heat_generators_stove',
#  'balcony_depth',
#  'bearing_wall_agglomerate',
#  'bearing_wall_bricks',
#  'bearing_wall_chipboard',
#  'bearing_wall_concrete',
#  'bearing_wall_gritstone',
#  'bearing_wall_indetermined',
#  'bearing_wall_millstone',
#  'bearing_wall_other',
#  'bearing_wall_stone',
#  'bearing_wall_wood',
#  'building_category_condo',
#  'building_category_house',
#  'building_class_12_plus',
#  'building_class_2_to_11',
#  'building_class_indiv',
#  'building_year',
#  'clay_risk_level',
#  'consumption_measurement_date',
#  'has_air_conditioning',
#  'heat_generators_boiler',
#  'heat_generators_electric',
#  'heat_generators_heat_pump',
#  'heat_generators_solar',
#  'heat_generators_stove',
#  'heating_source_coal',
#  'heating_source_electricity',
#  'heating_source_gas',
#  'heating_source_network',
#  'heating_source_oil',
#  'heating_source_wood',
#  'is_crossing_building',
#  'lower_floor_material_brick',
#  'lower_floor_material_concrete',
#  'lower_floor_material_joist',
#  'lower_floor_material_metal',
#  'lower_floor_material_wood',
#  'lower_year_building',
#  'nb_parking_spaces',
#  'number_of_fronts',
#  'outer_wall_hollow',
#  'outer_wall_thickness',
#  'renewable_energy_sources',
#  'solar_heating',
#  'solar_water_heating',
#  'upper_floor_LNC',
#  'upper_year_building',
#  'wall_insulation_external',
#  'wall_insulation_insulated',
#  'wall_insulation_internal',
#  'wall_insulation_mob',
#  'wall_insulation_reflection',
#  'water_heater_boiler',
#  'water_heater_heater',
#  'water_heater_tank',
#  'water_heating_coal',
#  'water_heating_electricity',
#  'water_heating_gas',
#  'water_heating_network',
#  'water_heating_oil',
#  'water_heating_wood',
#  'window_orientation_east',
#  'window_orientation_north',
#  'window_orientation_south',
#  'window_orientation_west']

# %%
if SMALL_DATASET:
    np.save("datasets/train/X_small.npy", X_train)
else:
    np.save("datasets/train/X_big.npy", X_train)

# %% [markdown]
# # X_test

# %%
print(X_test.shape)

X_test = feature_extractor.transform(X_test)

print(X_test.shape)

X_test = data_preprocessor.transform(X_test)

print(X_test.shape)
# Out:
# (4949, 71)
# (4949, 118)
# (4949, 263)

# %%
if SMALL_DATASET:
    np.save("datasets/test/X_test_small.npy", X_test)
else:
    np.save("datasets/test/X_test_big.npy", X_test)

# %%
X_train.isna().sum()[X_train.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
X_test.isna().sum()[X_test.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# for j in range(X_train.shape[1]):
#     for i in range(X_train.shape[0]):
#         if type(X_train.iloc[i, j]) == str:
#             print(X_train.iloc[i, j])
